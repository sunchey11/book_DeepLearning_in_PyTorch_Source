# %% [markdown]
# # 手写数字识别卷积神经网络
#
# 本文件是为了配合“迁移学习”内容而编写的文件，它的作用是将训练手写识别卷积神经网络，并将其保存在硬盘上以便迁移学习的时候能够读取该文件
# 本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
# 导入所需要的包，请保证torchvision已经在你的环境中安装好
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import torchvision.datasets as dsets
import torchvision.transforms as transforms

import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
# Hyper Parameters 
image_size = 28  #图像的总尺寸28*28
num_classes = 10  #标签的种类数
num_epochs = 20  #训练的总循环周期
batch_size = 64
learning_rate = 0.001

# 加载MINIST数据，如果没有下载过，就会在当前路径下新建/data子目录，并把文件存放其中

train_dataset = dsets.MNIST(root='./data',  #文件存放路径
                            train=True,   #提取训练集
                            transform=transforms.ToTensor(),  #将图像转化为Tensor
                            download=True)

test_dataset = dsets.MNIST(root='./data', 
                           train=False, 
                           transform=transforms.ToTensor())

# 训练数据集的加载器，自动将数据分割成batch，顺序随机打乱
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)
# 测试数据集的加载器，自动将数据分割成batch
permutes = np.random.permutation(range(len(test_dataset)))
indices_val = permutes[:5000]
indices_test = permutes[5000:]
sampler_val = torch.utils.data.sampler.SubsetRandomSampler(indices_val)
sampler_test = torch.utils.data.sampler.SubsetRandomSampler(indices_test)
validation_loader = torch.utils.data.DataLoader(dataset =train_dataset,
                                                batch_size = batch_size,
                                                shuffle = False,
                                                sampler = sampler_val
                                               )
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          shuffle=False,
                                          sampler = sampler_test
                                         )

# %%
#定义卷积神经网络：4和8为人为指定的两个卷积层的厚度
depth = [4, 8]
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 4, 5, padding = 2) #输入通道为1，输出通道为4，窗口大小为5，padding为2
        self.pool = nn.MaxPool2d(2, 2) #一个窗口为2*2的pooling运算
        self.conv2 = nn.Conv2d(depth[0], depth[1], 5, padding = 2) #第二层卷积，输入通道为depth[0], 输出通道为depth[1]，窗口wei15，padding为2
        self.fc1 = nn.Linear(image_size // 4 * image_size // 4 * depth[1] , 512) #一个线性连接层，输入尺寸为最后一层立方体的平铺，输出层512个节点
        self.fc2 = nn.Linear(512, num_classes) #最后一层线性分类单元，输入为

    def forward(self, x):
        #神经网络完成一步前馈运算的过程，从输入到输出
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        # 将立体的Tensor全部转换成一维的Tensor。两次pooling操作，所以图像维度减少了1/4
        x = x.view(-1, image_size // 4 * image_size // 4 * depth[1])
        x = F.relu(self.fc1(x)) #全链接，激活函数
        x = F.dropout(x, training=self.training) #以默认为0.5的概率对这一层进行dropout操作
        x = self.fc2(x) #全链接，激活函数
        x = F.log_softmax(x, dim = 1) #log_softmax可以理解为概率对数值
        return x
    
    def retrieve_features(self, x):
        #提取卷积神经网络的特征图的函数，返回feature_map1, feature_map2为前两层卷积层的特征图
        feature_map1 = F.relu(self.conv1(x))
        x = self.pool(feature_map1)
        feature_map2 = F.relu(self.conv2(x))
        return (feature_map1, feature_map2)

# %%
def rightness(predictions, labels):
    """计算预测错误率的函数，其中predictions是模型给出的一组预测结果，batch_size行10列的矩阵，labels是数据之中的正确答案"""
    pred = torch.max(predictions.data, 1)[1] # 对于任意一行（一个样本）的输出值的第1个维度，求最大，得到每一行的最大元素的下标
    rights = pred.eq(labels.data.view_as(pred)).sum() #将下标与labels中包含的类别进行比较，并累计得到比较正确的数量
    return rights, len(labels) #返回正确的数量和这一次一共比较了多少元素
net = ConvNet() #新建一个卷积神经网络的实例

criterion = nn.CrossEntropyLoss() #Loss函数的定义
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9) #定义优化器

record = [] #记录准确率等数值的容器
weights = [] #每若干步就记录一次卷积核

#开始训练循环
for epoch in range(num_epochs):
    
    train_rights = [] #记录训练数据集准确率的容器
    for batch_idx, (data, target) in enumerate(train_loader):  #针对容器中的每一个批进行循环
        data, target = data.clone().detach().requires_grad_(True), target.clone().detach() #data为图像，target为标签
        net.train() # 给网络模型做标记，标志说模型在训练集上训练
        output = net(data) #完成一次预测
        loss = criterion(output, target) #计算误差
        optimizer.zero_grad() #清空梯度
        loss.backward() #反向传播
        optimizer.step() #一步随机梯度下降
        right = rightness(output, target) #计算准确率所需数值，返回正确的数值为（正确样例数，总样本数）
        train_rights.append(right) #将计算结果装到列表容器中

    
        if batch_idx % 100 == 0: #每间隔100个batch执行一次
            
            #train_r为一个二元组，分别记录训练集中分类正确的数量和该集合中总的样本数
            train_r = (sum([tup[0] for tup in train_rights]), sum([tup[1] for tup in train_rights]))
            
            net.eval() # 给网络模型做标记，标志说模型在训练集上训练
            val_rights = [] #记录校验数据集准确率的容器
            for (data, target) in validation_loader:
                data, target = data.clone().detach().requires_grad_(True), target.clone().detach() 
                output = net(data) #完成一次预测
                right = rightness(output, target) #计算准确率所需数值，返回正确的数值为（正确样例数，总样本数）
                val_rights.append(right)
            
            #val_r为一个二元组，分别记录校验集中分类正确的数量和该集合中总的样本数
            val_r = (sum([tup[0] for tup in val_rights]), sum([tup[1] for tup in val_rights]))
            
            #打印准确率等数值，其中正确率为本训练周期Epoch开始后到目前撮的正确率的平均值
            print('训练周期: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}\t训练正确率: {:.2f}%\t校验正确率: {:.2f}%'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader),
                loss.data, 
                100. * train_r[0].numpy() / train_r[1], 
                100. * val_r[0].numpy() / val_r[1]))
            
            #将准确率和权重等数值加载到容器中，以方便后续处理
            record.append((100 - 100. * train_r[0].numpy() / train_r[1], 100 - 100. * val_r[0].numpy() / val_r[1]))
            weights.append([net.conv1.weight.data.clone(), net.conv1.bias.data.clone(), 
                            net.conv2.weight.data.clone(), net.conv2.bias.data.clone()])
# Out:
# 训练周期: 0 [0/60000 (0%)]	Loss: 2.302183	训练正确率: 10.94%	校验正确率: 7.90%
# 训练周期: 0 [800/60000 (11%)]	Loss: 2.306576	训练正确率: 9.07%	校验正确率: 10.74%
# 训练周期: 0 [1600/60000 (21%)]	Loss: 2.309405	训练正确率: 9.41%	校验正确率: 10.14%
# 训练周期: 0 [2400/60000 (32%)]	Loss: 2.300580	训练正确率: 10.42%	校验正确率: 10.26%
# 训练周期: 0 [3200/60000 (43%)]	Loss: 2.297560	训练正确率: 11.13%	校验正确率: 20.08%
# 训练周期: 0 [4000/60000 (53%)]	Loss: 2.294925	训练正确率: 12.29%	校验正确率: 25.32%
# 训练周期: 0 [4800/60000 (64%)]	Loss: 2.301019	训练正确率: 13.45%	校验正确率: 24.28%
# 训练周期: 0 [5600/60000 (75%)]	Loss: 2.292622	训练正确率: 14.66%	校验正确率: 32.86%
# 训练周期: 0 [6400/60000 (85%)]	Loss: 2.277537	训练正确率: 16.00%	校验正确率: 42.88%
# 训练周期: 0 [7200/60000 (96%)]	Loss: 2.267104	训练正确率: 17.15%	校验正确率: 43.52%
# 训练周期: 1 [0/60000 (0%)]	Loss: 2.241189	训练正确率: 28.12%	校验正确率: 39.36%
# 训练周期: 1 [800/60000 (11%)]	Loss: 2.188735	训练正确率: 30.07%	校验正确率: 49.52%
# 训练周期: 1 [1600/60000 (21%)]	Loss: 1.783105	训练正确率: 37.57%	校验正确率: 69.90%
# 训练周期: 1 [2400/60000 (32%)]	Loss: 0.926362	训练正确率: 46.97%	校验正确率: 78.58%
# 训练周期: 1 [3200/60000 (43%)]	Loss: 0.587075	训练正确率: 54.11%	校验正确率: 83.46%
# 训练周期: 1 [4000/60000 (53%)]	Loss: 0.728069	训练正确率: 59.33%	校验正确率: 86.92%
# 训练周期: 1 [4800/60000 (64%)]	Loss: 0.546732	训练正确率: 63.29%	校验正确率: 88.24%
# 训练周期: 1 [5600/60000 (75%)]	Loss: 0.346088	训练正确率: 66.44%	校验正确率: 89.64%
# 训练周期: 1 [6400/60000 (85%)]	Loss: 0.661402	训练正确率: 68.97%	校验正确率: 90.20%
# 训练周期: 1 [7200/60000 (96%)]	Loss: 0.294762	训练正确率: 71.14%	校验正确率: 90.72%
# 训练周期: 2 [0/60000 (0%)]	Loss: 0.404846	训练正确率: 89.06%	校验正确率: 91.34%
# 训练周期: 2 [800/60000 (11%)]	Loss: 0.411689	训练正确率: 88.88%	校验正确率: 92.28%
# 训练周期: 2 [1600/60000 (21%)]	Loss: 0.279767	训练正确率: 89.54%	校验正确率: 92.34%
# 训练周期: 2 [2400/60000 (32%)]	Loss: 0.267028	训练正确率: 89.72%	校验正确率: 91.76%
# 训练周期: 2 [3200/60000 (43%)]	Loss: 0.284981	训练正确率: 89.83%	校验正确率: 92.72%
# 训练周期: 2 [4000/60000 (53%)]	Loss: 0.259668	训练正确率: 90.10%	校验正确率: 93.52%
# 训练周期: 2 [4800/60000 (64%)]	Loss: 0.405284	训练正确率: 90.25%	校验正确率: 93.62%
# 训练周期: 2 [5600/60000 (75%)]	Loss: 0.171908	训练正确率: 90.50%	校验正确率: 93.88%
# 训练周期: 2 [6400/60000 (85%)]	Loss: 0.394502	训练正确率: 90.62%	校验正确率: 94.02%
# 训练周期: 2 [7200/60000 (96%)]	Loss: 0.291879	训练正确率: 90.83%	校验正确率: 94.30%
# 训练周期: 3 [0/60000 (0%)]	Loss: 0.165725	训练正确率: 95.31%	校验正确率: 94.22%
# 训练周期: 3 [800/60000 (11%)]	Loss: 0.150858	训练正确率: 92.42%	校验正确率: 94.48%
# 训练周期: 3 [1600/60000 (21%)]	Loss: 0.148943	训练正确率: 92.41%	校验正确率: 94.62%
# 训练周期: 3 [2400/60000 (32%)]	Loss: 0.080370	训练正确率: 92.77%	校验正确率: 94.86%
# 训练周期: 3 [3200/60000 (43%)]	Loss: 0.519731	训练正确率: 92.92%	校验正确率: 95.28%
# 训练周期: 3 [4000/60000 (53%)]	Loss: 0.285617	训练正确率: 93.06%	校验正确率: 94.90%
# 训练周期: 3 [4800/60000 (64%)]	Loss: 0.126933	训练正确率: 93.20%	校验正确率: 95.38%
# 训练周期: 3 [5600/60000 (75%)]	Loss: 0.204512	训练正确率: 93.29%	校验正确率: 95.54%
# 训练周期: 3 [6400/60000 (85%)]	Loss: 0.207637	训练正确率: 93.30%	校验正确率: 95.14%
# 训练周期: 3 [7200/60000 (96%)]	Loss: 0.113349	训练正确率: 93.35%	校验正确率: 95.56%
# 训练周期: 4 [0/60000 (0%)]	Loss: 0.145848	训练正确率: 95.31%	校验正确率: 95.54%
# 训练周期: 4 [800/60000 (11%)]	Loss: 0.161335	训练正确率: 94.26%	校验正确率: 95.52%
# 训练周期: 4 [1600/60000 (21%)]	Loss: 0.127230	训练正确率: 94.21%	校验正确率: 95.74%
# 训练周期: 4 [2400/60000 (32%)]	Loss: 0.199936	训练正确率: 94.22%	校验正确率: 95.78%
# 训练周期: 4 [3200/60000 (43%)]	Loss: 0.204524	训练正确率: 94.17%	校验正确率: 95.92%
# 训练周期: 4 [4000/60000 (53%)]	Loss: 0.153969	训练正确率: 94.30%	校验正确率: 95.84%
# 训练周期: 4 [4800/60000 (64%)]	Loss: 0.117559	训练正确率: 94.34%	校验正确率: 96.12%
# 训练周期: 4 [5600/60000 (75%)]	Loss: 0.310111	训练正确率: 94.41%	校验正确率: 95.94%
# 训练周期: 4 [6400/60000 (85%)]	Loss: 0.118722	训练正确率: 94.36%	校验正确率: 96.20%
# 训练周期: 4 [7200/60000 (96%)]	Loss: 0.242306	训练正确率: 94.44%	校验正确率: 96.28%
# 训练周期: 5 [0/60000 (0%)]	Loss: 0.297939	训练正确率: 90.62%	校验正确率: 96.06%
# 训练周期: 5 [800/60000 (11%)]	Loss: 0.078356	训练正确率: 94.42%	校验正确率: 96.26%
# 训练周期: 5 [1600/60000 (21%)]	Loss: 0.145391	训练正确率: 94.89%	校验正确率: 96.16%
# 训练周期: 5 [2400/60000 (32%)]	Loss: 0.074860	训练正确率: 95.01%	校验正确率: 96.54%
# 训练周期: 5 [3200/60000 (43%)]	Loss: 0.098594	训练正确率: 95.06%	校验正确率: 96.46%
# 训练周期: 5 [4000/60000 (53%)]	Loss: 0.129175	训练正确率: 95.12%	校验正确率: 96.70%
# 训练周期: 5 [4800/60000 (64%)]	Loss: 0.209319	训练正确率: 95.09%	校验正确率: 96.70%
# 训练周期: 5 [5600/60000 (75%)]	Loss: 0.117379	训练正确率: 95.07%	校验正确率: 96.64%
# 训练周期: 5 [6400/60000 (85%)]	Loss: 0.201414	训练正确率: 95.12%	校验正确率: 96.76%
# 训练周期: 5 [7200/60000 (96%)]	Loss: 0.167591	训练正确率: 95.19%	校验正确率: 96.84%
# 训练周期: 6 [0/60000 (0%)]	Loss: 0.249545	训练正确率: 92.19%	校验正确率: 96.72%
# 训练周期: 6 [800/60000 (11%)]	Loss: 0.162503	训练正确率: 95.37%	校验正确率: 96.70%
# 训练周期: 6 [1600/60000 (21%)]	Loss: 0.122810	训练正确率: 95.48%	校验正确率: 96.80%
# 训练周期: 6 [2400/60000 (32%)]	Loss: 0.130684	训练正确率: 95.57%	校验正确率: 96.84%
# 训练周期: 6 [3200/60000 (43%)]	Loss: 0.097776	训练正确率: 95.55%	校验正确率: 96.84%
# 训练周期: 6 [4000/60000 (53%)]	Loss: 0.156873	训练正确率: 95.59%	校验正确率: 96.76%
# 训练周期: 6 [4800/60000 (64%)]	Loss: 0.149142	训练正确率: 95.71%	校验正确率: 96.78%
# 训练周期: 6 [5600/60000 (75%)]	Loss: 0.155369	训练正确率: 95.75%	校验正确率: 96.78%
# 训练周期: 6 [6400/60000 (85%)]	Loss: 0.189330	训练正确率: 95.77%	校验正确率: 97.08%
# 训练周期: 6 [7200/60000 (96%)]	Loss: 0.161012	训练正确率: 95.80%	校验正确率: 97.00%
# 训练周期: 7 [0/60000 (0%)]	Loss: 0.072197	训练正确率: 96.88%	校验正确率: 96.94%
# 训练周期: 7 [800/60000 (11%)]	Loss: 0.088115	训练正确率: 96.12%	校验正确率: 96.94%
# 训练周期: 7 [1600/60000 (21%)]	Loss: 0.083377	训练正确率: 96.12%	校验正确率: 97.14%
# 训练周期: 7 [2400/60000 (32%)]	Loss: 0.069798	训练正确率: 95.93%	校验正确率: 96.98%
# 训练周期: 7 [3200/60000 (43%)]	Loss: 0.094937	训练正确率: 95.98%	校验正确率: 97.28%
# 训练周期: 7 [4000/60000 (53%)]	Loss: 0.180011	训练正确率: 96.03%	校验正确率: 97.10%
# 训练周期: 7 [4800/60000 (64%)]	Loss: 0.097915	训练正确率: 96.03%	校验正确率: 97.12%
# 训练周期: 7 [5600/60000 (75%)]	Loss: 0.062287	训练正确率: 96.02%	校验正确率: 97.18%
# 训练周期: 7 [6400/60000 (85%)]	Loss: 0.063746	训练正确率: 96.05%	校验正确率: 97.32%
# 训练周期: 7 [7200/60000 (96%)]	Loss: 0.119526	训练正确率: 96.04%	校验正确率: 97.18%
# 训练周期: 8 [0/60000 (0%)]	Loss: 0.134062	训练正确率: 95.31%	校验正确率: 97.30%
# 训练周期: 8 [800/60000 (11%)]	Loss: 0.118716	训练正确率: 96.07%	校验正确率: 97.38%
# 训练周期: 8 [1600/60000 (21%)]	Loss: 0.077976	训练正确率: 96.30%	校验正确率: 97.44%
# 训练周期: 8 [2400/60000 (32%)]	Loss: 0.042768	训练正确率: 96.38%	校验正确率: 97.22%
# 训练周期: 8 [3200/60000 (43%)]	Loss: 0.030229	训练正确率: 96.49%	校验正确率: 97.44%
# 训练周期: 8 [4000/60000 (53%)]	Loss: 0.086928	训练正确率: 96.52%	校验正确率: 97.18%
# 训练周期: 8 [4800/60000 (64%)]	Loss: 0.144865	训练正确率: 96.50%	校验正确率: 97.30%
# 训练周期: 8 [5600/60000 (75%)]	Loss: 0.177021	训练正确率: 96.49%	校验正确率: 97.36%
# 训练周期: 8 [6400/60000 (85%)]	Loss: 0.052593	训练正确率: 96.43%	校验正确率: 97.68%
# 训练周期: 8 [7200/60000 (96%)]	Loss: 0.097801	训练正确率: 96.44%	校验正确率: 97.40%
# 训练周期: 9 [0/60000 (0%)]	Loss: 0.107404	训练正确率: 92.19%	校验正确率: 97.58%
# 训练周期: 9 [800/60000 (11%)]	Loss: 0.159366	训练正确率: 96.44%	校验正确率: 97.42%
# 训练周期: 9 [1600/60000 (21%)]	Loss: 0.037803	训练正确率: 96.76%	校验正确率: 97.64%
# 训练周期: 9 [2400/60000 (32%)]	Loss: 0.076740	训练正确率: 96.81%	校验正确率: 97.56%
# 训练周期: 9 [3200/60000 (43%)]	Loss: 0.143519	训练正确率: 96.77%	校验正确率: 97.60%
# 训练周期: 9 [4000/60000 (53%)]	Loss: 0.044905	训练正确率: 96.76%	校验正确率: 97.70%
# 训练周期: 9 [4800/60000 (64%)]	Loss: 0.219880	训练正确率: 96.75%	校验正确率: 97.30%
# 训练周期: 9 [5600/60000 (75%)]	Loss: 0.153888	训练正确率: 96.68%	校验正确率: 97.64%
# 训练周期: 9 [6400/60000 (85%)]	Loss: 0.114431	训练正确率: 96.69%	校验正确率: 97.64%
# 训练周期: 9 [7200/60000 (96%)]	Loss: 0.096823	训练正确率: 96.68%	校验正确率: 97.68%
# 训练周期: 10 [0/60000 (0%)]	Loss: 0.282478	训练正确率: 93.75%	校验正确率: 97.92%
# 训练周期: 10 [800/60000 (11%)]	Loss: 0.135659	训练正确率: 96.47%	校验正确率: 97.72%
# 训练周期: 10 [1600/60000 (21%)]	Loss: 0.058414	训练正确率: 96.84%	校验正确率: 97.56%
# 训练周期: 10 [2400/60000 (32%)]	Loss: 0.079104	训练正确率: 96.83%	校验正确率: 97.62%
# 训练周期: 10 [3200/60000 (43%)]	Loss: 0.127609	训练正确率: 96.73%	校验正确率: 97.86%
# 训练周期: 10 [4000/60000 (53%)]	Loss: 0.092351	训练正确率: 96.80%	校验正确率: 97.70%
# 训练周期: 10 [4800/60000 (64%)]	Loss: 0.030495	训练正确率: 96.84%	校验正确率: 97.86%
# 训练周期: 10 [5600/60000 (75%)]	Loss: 0.058008	训练正确率: 96.88%	校验正确率: 97.84%
# 训练周期: 10 [6400/60000 (85%)]	Loss: 0.228351	训练正确率: 96.91%	校验正确率: 97.62%
# 训练周期: 10 [7200/60000 (96%)]	Loss: 0.082185	训练正确率: 96.90%	校验正确率: 97.90%
# 训练周期: 11 [0/60000 (0%)]	Loss: 0.125688	训练正确率: 95.31%	校验正确率: 97.60%
# 训练周期: 11 [800/60000 (11%)]	Loss: 0.021002	训练正确率: 97.18%	校验正确率: 97.72%
# 训练周期: 11 [1600/60000 (21%)]	Loss: 0.033216	训练正确率: 97.08%	校验正确率: 97.94%
# 训练周期: 11 [2400/60000 (32%)]	Loss: 0.136498	训练正确率: 97.08%	校验正确率: 98.20%
# 训练周期: 11 [3200/60000 (43%)]	Loss: 0.077066	训练正确率: 97.01%	校验正确率: 97.94%
# 训练周期: 11 [4000/60000 (53%)]	Loss: 0.083516	训练正确率: 97.05%	校验正确率: 97.82%
# 训练周期: 11 [4800/60000 (64%)]	Loss: 0.075378	训练正确率: 97.03%	校验正确率: 98.00%
# 训练周期: 11 [5600/60000 (75%)]	Loss: 0.075283	训练正确率: 97.08%	校验正确率: 97.76%
# 训练周期: 11 [6400/60000 (85%)]	Loss: 0.066443	训练正确率: 97.07%	校验正确率: 97.70%
# 训练周期: 11 [7200/60000 (96%)]	Loss: 0.244280	训练正确率: 97.11%	校验正确率: 97.76%
# 训练周期: 12 [0/60000 (0%)]	Loss: 0.055043	训练正确率: 100.00%	校验正确率: 97.78%
# 训练周期: 12 [800/60000 (11%)]	Loss: 0.080297	训练正确率: 97.00%	校验正确率: 97.74%
# 训练周期: 12 [1600/60000 (21%)]	Loss: 0.098425	训练正确率: 96.95%	校验正确率: 97.82%
# 训练周期: 12 [2400/60000 (32%)]	Loss: 0.167289	训练正确率: 96.99%	校验正确率: 97.82%
# 训练周期: 12 [3200/60000 (43%)]	Loss: 0.279012	训练正确率: 97.07%	校验正确率: 97.76%
# 训练周期: 12 [4000/60000 (53%)]	Loss: 0.154879	训练正确率: 97.11%	校验正确率: 97.98%
# 训练周期: 12 [4800/60000 (64%)]	Loss: 0.103404	训练正确率: 97.22%	校验正确率: 98.12%
# 训练周期: 12 [5600/60000 (75%)]	Loss: 0.204012	训练正确率: 97.23%	校验正确率: 97.92%
# 训练周期: 12 [6400/60000 (85%)]	Loss: 0.066496	训练正确率: 97.21%	校验正确率: 98.00%
# 训练周期: 12 [7200/60000 (96%)]	Loss: 0.076787	训练正确率: 97.23%	校验正确率: 97.98%
# 训练周期: 13 [0/60000 (0%)]	Loss: 0.097130	训练正确率: 96.88%	校验正确率: 97.94%
# 训练周期: 13 [800/60000 (11%)]	Loss: 0.059876	训练正确率: 97.71%	校验正确率: 98.00%
# 训练周期: 13 [1600/60000 (21%)]	Loss: 0.028402	训练正确率: 97.61%	校验正确率: 98.00%
# 训练周期: 13 [2400/60000 (32%)]	Loss: 0.027435	训练正确率: 97.50%	校验正确率: 98.12%
# 训练周期: 13 [3200/60000 (43%)]	Loss: 0.130211	训练正确率: 97.40%	校验正确率: 98.12%
# 训练周期: 13 [4000/60000 (53%)]	Loss: 0.174767	训练正确率: 97.33%	校验正确率: 97.92%
# 训练周期: 13 [4800/60000 (64%)]	Loss: 0.034377	训练正确率: 97.37%	校验正确率: 97.98%
# 训练周期: 13 [5600/60000 (75%)]	Loss: 0.060152	训练正确率: 97.39%	校验正确率: 98.02%
# 训练周期: 13 [6400/60000 (85%)]	Loss: 0.057598	训练正确率: 97.40%	校验正确率: 98.06%
# 训练周期: 13 [7200/60000 (96%)]	Loss: 0.037380	训练正确率: 97.39%	校验正确率: 97.90%
# 训练周期: 14 [0/60000 (0%)]	Loss: 0.028567	训练正确率: 98.44%	校验正确率: 97.98%
# 训练周期: 14 [800/60000 (11%)]	Loss: 0.059269	训练正确率: 97.48%	校验正确率: 98.14%
# 训练周期: 14 [1600/60000 (21%)]	Loss: 0.184654	训练正确率: 97.29%	校验正确率: 98.16%
# 训练周期: 14 [2400/60000 (32%)]	Loss: 0.065887	训练正确率: 97.44%	校验正确率: 98.20%
# 训练周期: 14 [3200/60000 (43%)]	Loss: 0.038628	训练正确率: 97.42%	校验正确率: 98.02%
# 训练周期: 14 [4000/60000 (53%)]	Loss: 0.026446	训练正确率: 97.38%	校验正确率: 98.12%
# 训练周期: 14 [4800/60000 (64%)]	Loss: 0.246901	训练正确率: 97.41%	校验正确率: 98.22%
# 训练周期: 14 [5600/60000 (75%)]	Loss: 0.117215	训练正确率: 97.44%	校验正确率: 98.24%
# 训练周期: 14 [6400/60000 (85%)]	Loss: 0.031979	训练正确率: 97.46%	校验正确率: 98.10%
# 训练周期: 14 [7200/60000 (96%)]	Loss: 0.077611	训练正确率: 97.47%	校验正确率: 98.14%
# 训练周期: 15 [0/60000 (0%)]	Loss: 0.110632	训练正确率: 96.88%	校验正确率: 98.36%
# 训练周期: 15 [800/60000 (11%)]	Loss: 0.115951	训练正确率: 97.62%	校验正确率: 98.30%
# 训练周期: 15 [1600/60000 (21%)]	Loss: 0.101754	训练正确率: 97.61%	校验正确率: 98.22%
# 训练周期: 15 [2400/60000 (32%)]	Loss: 0.068117	训练正确率: 97.59%	校验正确率: 98.16%
# 训练周期: 15 [3200/60000 (43%)]	Loss: 0.047238	训练正确率: 97.65%	校验正确率: 98.24%
# 训练周期: 15 [4000/60000 (53%)]	Loss: 0.035878	训练正确率: 97.60%	校验正确率: 98.36%
# 训练周期: 15 [4800/60000 (64%)]	Loss: 0.059536	训练正确率: 97.62%	校验正确率: 98.28%
# 训练周期: 15 [5600/60000 (75%)]	Loss: 0.067053	训练正确率: 97.62%	校验正确率: 98.22%
# 训练周期: 15 [6400/60000 (85%)]	Loss: 0.098233	训练正确率: 97.61%	校验正确率: 98.44%
# 训练周期: 15 [7200/60000 (96%)]	Loss: 0.079349	训练正确率: 97.62%	校验正确率: 98.14%
# 训练周期: 16 [0/60000 (0%)]	Loss: 0.176557	训练正确率: 95.31%	校验正确率: 98.14%
# 训练周期: 16 [800/60000 (11%)]	Loss: 0.120241	训练正确率: 97.57%	校验正确率: 98.06%
# 训练周期: 16 [1600/60000 (21%)]	Loss: 0.127227	训练正确率: 97.61%	校验正确率: 98.40%
# 训练周期: 16 [2400/60000 (32%)]	Loss: 0.016911	训练正确率: 97.70%	校验正确率: 98.28%
# 训练周期: 16 [3200/60000 (43%)]	Loss: 0.083573	训练正确率: 97.76%	校验正确率: 98.22%
# 训练周期: 16 [4000/60000 (53%)]	Loss: 0.044406	训练正确率: 97.72%	校验正确率: 98.30%
# 训练周期: 16 [4800/60000 (64%)]	Loss: 0.022675	训练正确率: 97.71%	校验正确率: 98.34%
# 训练周期: 16 [5600/60000 (75%)]	Loss: 0.060092	训练正确率: 97.68%	校验正确率: 98.34%
# 训练周期: 16 [6400/60000 (85%)]	Loss: 0.079300	训练正确率: 97.68%	校验正确率: 98.40%
# 训练周期: 16 [7200/60000 (96%)]	Loss: 0.026693	训练正确率: 97.72%	校验正确率: 98.42%
# 训练周期: 17 [0/60000 (0%)]	Loss: 0.077850	训练正确率: 96.88%	校验正确率: 98.36%
# 训练周期: 17 [800/60000 (11%)]	Loss: 0.040545	训练正确率: 97.77%	校验正确率: 98.48%
# 训练周期: 17 [1600/60000 (21%)]	Loss: 0.061327	训练正确率: 97.83%	校验正确率: 98.44%
# 训练周期: 17 [2400/60000 (32%)]	Loss: 0.073046	训练正确率: 97.83%	校验正确率: 98.32%
# 训练周期: 17 [3200/60000 (43%)]	Loss: 0.012841	训练正确率: 97.85%	校验正确率: 98.34%
# 训练周期: 17 [4000/60000 (53%)]	Loss: 0.163904	训练正确率: 97.76%	校验正确率: 98.46%
# 训练周期: 17 [4800/60000 (64%)]	Loss: 0.040765	训练正确率: 97.72%	校验正确率: 98.40%
# 训练周期: 17 [5600/60000 (75%)]	Loss: 0.089397	训练正确率: 97.75%	校验正确率: 98.36%
# 训练周期: 17 [6400/60000 (85%)]	Loss: 0.061202	训练正确率: 97.75%	校验正确率: 98.36%
# 训练周期: 17 [7200/60000 (96%)]	Loss: 0.071787	训练正确率: 97.75%	校验正确率: 98.52%
# 训练周期: 18 [0/60000 (0%)]	Loss: 0.038923	训练正确率: 98.44%	校验正确率: 98.54%
# 训练周期: 18 [800/60000 (11%)]	Loss: 0.118991	训练正确率: 98.22%	校验正确率: 98.44%
# 训练周期: 18 [1600/60000 (21%)]	Loss: 0.123314	训练正确率: 97.97%	校验正确率: 98.40%
# 训练周期: 18 [2400/60000 (32%)]	Loss: 0.047671	训练正确率: 97.97%	校验正确率: 98.54%
# 训练周期: 18 [3200/60000 (43%)]	Loss: 0.161864	训练正确率: 97.93%	校验正确率: 98.42%
# 训练周期: 18 [4000/60000 (53%)]	Loss: 0.067035	训练正确率: 97.89%	校验正确率: 98.42%
# 训练周期: 18 [4800/60000 (64%)]	Loss: 0.111303	训练正确率: 97.92%	校验正确率: 98.46%
# 训练周期: 18 [5600/60000 (75%)]	Loss: 0.048372	训练正确率: 97.92%	校验正确率: 98.46%
# 训练周期: 18 [6400/60000 (85%)]	Loss: 0.152010	训练正确率: 97.88%	校验正确率: 98.50%
# 训练周期: 18 [7200/60000 (96%)]	Loss: 0.034850	训练正确率: 97.85%	校验正确率: 98.64%
# 训练周期: 19 [0/60000 (0%)]	Loss: 0.068859	训练正确率: 98.44%	校验正确率: 98.52%
# 训练周期: 19 [800/60000 (11%)]	Loss: 0.155628	训练正确率: 97.65%	校验正确率: 98.60%
# 训练周期: 19 [1600/60000 (21%)]	Loss: 0.070309	训练正确率: 97.85%	校验正确率: 98.64%
# 训练周期: 19 [2400/60000 (32%)]	Loss: 0.045073	训练正确率: 97.90%	校验正确率: 98.54%
# 训练周期: 19 [3200/60000 (43%)]	Loss: 0.115047	训练正确率: 98.00%	校验正确率: 98.62%
# 训练周期: 19 [4000/60000 (53%)]	Loss: 0.003469	训练正确率: 98.04%	校验正确率: 98.46%
# 训练周期: 19 [4800/60000 (64%)]	Loss: 0.015202	训练正确率: 98.08%	校验正确率: 98.48%
# 训练周期: 19 [5600/60000 (75%)]	Loss: 0.051002	训练正确率: 98.07%	校验正确率: 98.44%
# 训练周期: 19 [6400/60000 (85%)]	Loss: 0.068181	训练正确率: 98.05%	校验正确率: 98.60%
# 训练周期: 19 [7200/60000 (96%)]	Loss: 0.056513	训练正确率: 98.00%	校验正确率: 98.58%

# %% [markdown]
# ## 保存模型

# %%
# 在这里保存已经训练好的神经网络
torch.save(net, 'minst_conv_checkpoint') #后面的字符串为保存文件的路径

# %%
#提取第一层卷积层的卷积核
plt.figure(figsize = (10, 7))
for i in range(4):
    plt.subplot(1,4,i + 1)
    plt.imshow(net.conv1.weight.data.numpy()[i,0,...])

# %%
# 绘制第二层的卷积核
plt.figure(figsize = (15, 10))
for i in range(4):
    for j in range(8):
        plt.subplot(4, 8, i * 8 + j + 1)
        plt.imshow(net.conv2.weight.data.numpy()[j, i,...])
